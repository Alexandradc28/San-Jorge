-- %% [markdown]
-- # [MrPizza]

-- %%
USE [master]
GO

-- %%
/****** Object:  Database [MrPizza]    Script Date: 30/10/2024 12:09:54 p. m. ******/
CREATE DATABASE [MrPizza]
 CONTAINMENT = NONE
 ON  PRIMARY 
( NAME = N'MrPizza', FILENAME = N'C:\Program Files\Microsoft SQL Server\MSSQL16.MSSQLSERVER\MSSQL\DATA\MrPizza.mdf' , SIZE = 8192KB , MAXSIZE = UNLIMITED, FILEGROWTH = 65536KB )
 LOG ON 
( NAME = N'MrPizza_log', FILENAME = N'C:\Program Files\Microsoft SQL Server\MSSQL16.MSSQLSERVER\MSSQL\DATA\MrPizza_log.ldf' , SIZE = 8192KB , MAXSIZE = 2048GB , FILEGROWTH = 65536KB )
 WITH CATALOG_COLLATION = DATABASE_DEFAULT, LEDGER = OFF
GO
ALTER DATABASE [MrPizza] SET COMPATIBILITY_LEVEL = 160
GO
IF (1 = FULLTEXTSERVICEPROPERTY('IsFullTextInstalled'))
begin
EXEC [MrPizza].[dbo].[sp_fulltext_database] @action = 'enable'
end
GO
ALTER DATABASE [MrPizza] SET ANSI_NULL_DEFAULT OFF 
GO
ALTER DATABASE [MrPizza] SET ANSI_NULLS OFF 
GO
ALTER DATABASE [MrPizza] SET ANSI_PADDING OFF 
GO
ALTER DATABASE [MrPizza] SET ANSI_WARNINGS OFF 
GO
ALTER DATABASE [MrPizza] SET ARITHABORT OFF 
GO
ALTER DATABASE [MrPizza] SET AUTO_CLOSE OFF 
GO
ALTER DATABASE [MrPizza] SET AUTO_SHRINK OFF 
GO
ALTER DATABASE [MrPizza] SET AUTO_UPDATE_STATISTICS ON 
GO
ALTER DATABASE [MrPizza] SET CURSOR_CLOSE_ON_COMMIT OFF 
GO
ALTER DATABASE [MrPizza] SET CURSOR_DEFAULT  GLOBAL 
GO
ALTER DATABASE [MrPizza] SET CONCAT_NULL_YIELDS_NULL OFF 
GO
ALTER DATABASE [MrPizza] SET NUMERIC_ROUNDABORT OFF 
GO
ALTER DATABASE [MrPizza] SET QUOTED_IDENTIFIER OFF 
GO
ALTER DATABASE [MrPizza] SET RECURSIVE_TRIGGERS OFF 
GO
ALTER DATABASE [MrPizza] SET  DISABLE_BROKER 
GO
ALTER DATABASE [MrPizza] SET AUTO_UPDATE_STATISTICS_ASYNC OFF 
GO
ALTER DATABASE [MrPizza] SET DATE_CORRELATION_OPTIMIZATION OFF 
GO
ALTER DATABASE [MrPizza] SET TRUSTWORTHY OFF 
GO
ALTER DATABASE [MrPizza] SET ALLOW_SNAPSHOT_ISOLATION OFF 
GO
ALTER DATABASE [MrPizza] SET PARAMETERIZATION SIMPLE 
GO
ALTER DATABASE [MrPizza] SET READ_COMMITTED_SNAPSHOT OFF 
GO
ALTER DATABASE [MrPizza] SET HONOR_BROKER_PRIORITY OFF 
GO
ALTER DATABASE [MrPizza] SET RECOVERY FULL 
GO
ALTER DATABASE [MrPizza] SET  MULTI_USER 
GO
ALTER DATABASE [MrPizza] SET PAGE_VERIFY CHECKSUM  
GO
ALTER DATABASE [MrPizza] SET DB_CHAINING OFF 
GO
ALTER DATABASE [MrPizza] SET FILESTREAM( NON_TRANSACTED_ACCESS = OFF ) 
GO
ALTER DATABASE [MrPizza] SET TARGET_RECOVERY_TIME = 60 SECONDS 
GO
ALTER DATABASE [MrPizza] SET DELAYED_DURABILITY = DISABLED 
GO
ALTER DATABASE [MrPizza] SET ACCELERATED_DATABASE_RECOVERY = OFF  
GO
EXEC sys.sp_db_vardecimal_storage_format N'MrPizza', N'ON'
GO
ALTER DATABASE [MrPizza] SET QUERY_STORE = ON
GO
ALTER DATABASE [MrPizza] SET QUERY_STORE (OPERATION_MODE = READ_WRITE, CLEANUP_POLICY = (STALE_QUERY_THRESHOLD_DAYS = 30), DATA_FLUSH_INTERVAL_SECONDS = 900, INTERVAL_LENGTH_MINUTES = 60, MAX_STORAGE_SIZE_MB = 1000, QUERY_CAPTURE_MODE = AUTO, SIZE_BASED_CLEANUP_MODE = AUTO, MAX_PLANS_PER_QUERY = 200, WAIT_STATS_CAPTURE_MODE = ON)
GO

-- %% [markdown]
-- # [soporte]

-- %%
USE [MrPizza]
GO

-- %%
/****** Object:  User [soporte]    Script Date: 30/10/2024 12:09:55 p. m. ******/
CREATE USER [soporte] FOR LOGIN [soporte] WITH DEFAULT_SCHEMA=[dbo]
GO

-- %% [markdown]
-- # [dbo].[Carrito]

-- %%
/****** Object:  Table [dbo].[Carrito]    Script Date: 30/10/2024 12:09:55 p. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Carrito](
	[id_carrito] [int] IDENTITY(1,1) NOT NULL,
	[cliente_id] [int] NULL,
PRIMARY KEY CLUSTERED 
(
	[id_carrito] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Categoria]

-- %%
/****** Object:  Table [dbo].[Categoria]    Script Date: 30/10/2024 12:09:55 p. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Categoria](
	[id_categoria] [int] IDENTITY(1,1) NOT NULL,
	[estado_id] [int] NULL,
	[nombre] [varchar](50) NOT NULL,
	[descripcion] [text] NULL,
PRIMARY KEY CLUSTERED 
(
	[id_categoria] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY] TEXTIMAGE_ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Cliente]

-- %%
/****** Object:  Table [dbo].[Cliente]    Script Date: 30/10/2024 12:09:55 p. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Cliente](
	[id_cliente] [int] IDENTITY(1,1) NOT NULL,
	[usuario_id] [int] NULL,
	[nombre] [varchar](50) NOT NULL,
	[apellido] [varchar](50) NOT NULL,
	[direccion] [text] NULL,
	[correo_electronico] [varchar](100) NOT NULL,
	[telefono] [varchar](20) NULL,
PRIMARY KEY CLUSTERED 
(
	[id_cliente] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY] TEXTIMAGE_ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Detalle_Carrito]

-- %%
/****** Object:  Table [dbo].[Detalle_Carrito]    Script Date: 30/10/2024 12:09:55 p. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Detalle_Carrito](
	[carrito_id] [int] NOT NULL,
	[producto_id] [int] NOT NULL,
PRIMARY KEY CLUSTERED 
(
	[carrito_id] ASC,
	[producto_id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Detalle_Pedido]

-- %%
/****** Object:  Table [dbo].[Detalle_Pedido]    Script Date: 30/10/2024 12:09:55 p. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Detalle_Pedido](
	[pedido_id] [int] NOT NULL,
	[producto_id] [int] NOT NULL,
	[cantidad] [int] NOT NULL,
	[monto] [decimal](6, 2) NOT NULL,
PRIMARY KEY CLUSTERED 
(
	[pedido_id] ASC,
	[producto_id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Estado]

-- %%
/****** Object:  Table [dbo].[Estado]    Script Date: 30/10/2024 12:09:55 p. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Estado](
	[id_estado] [int] IDENTITY(1,1) NOT NULL,
	[nombre] [varchar](50) NOT NULL,
	[descripcion] [text] NULL,
PRIMARY KEY CLUSTERED 
(
	[id_estado] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY] TEXTIMAGE_ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Pedido]

-- %%
/****** Object:  Table [dbo].[Pedido]    Script Date: 30/10/2024 12:09:55 p. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Pedido](
	[id_pedido] [int] IDENTITY(1,1) NOT NULL,
	[cliente_id] [int] NULL,
	[cocinero_id] [int] NULL,
	[repartidor_id] [int] NULL,
	[estado_id] [int] NULL,
	[fecha] [datetime] NOT NULL,
	[monto_total] [decimal](4, 2) NOT NULL,
PRIMARY KEY CLUSTERED 
(
	[id_pedido] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Personal]

-- %%
/****** Object:  Table [dbo].[Personal]    Script Date: 30/10/2024 12:09:55 p. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Personal](
	[id_personal] [int] IDENTITY(1,1) NOT NULL,
	[usuario_id] [int] NULL,
	[tipo_personal_id] [int] NULL,
	[estado_id] [int] NULL,
	[nombre] [varchar](50) NOT NULL,
	[apellido] [varchar](50) NOT NULL,
	[direccion] [text] NULL,
	[correo_electronico] [varchar](100) NOT NULL,
	[telefono] [varchar](20) NULL,
PRIMARY KEY CLUSTERED 
(
	[id_personal] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY] TEXTIMAGE_ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Producto]

-- %%
/****** Object:  Table [dbo].[Producto]    Script Date: 30/10/2024 12:09:55 p. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Producto](
	[id_producto] [int] IDENTITY(1,1) NOT NULL,
	[estado_id] [int] NULL,
	[categoria_id] [int] NULL,
	[nombre] [varchar](50) NOT NULL,
	[descripcion] [text] NULL,
	[tamanio] [varchar](50) NULL,
	[imagen_url] [varchar](255) NULL,
	[precio] [decimal](4, 2) NULL,
PRIMARY KEY CLUSTERED 
(
	[id_producto] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY] TEXTIMAGE_ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Rol]

-- %%
/****** Object:  Table [dbo].[Rol]    Script Date: 30/10/2024 12:09:55 p. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Rol](
	[id_rol] [int] IDENTITY(1,1) NOT NULL,
	[estado_id] [int] NULL,
	[nombre] [varchar](50) NOT NULL,
	[descripcion] [text] NULL,
PRIMARY KEY CLUSTERED 
(
	[id_rol] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY] TEXTIMAGE_ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Tipo_Personal]

-- %%
/****** Object:  Table [dbo].[Tipo_Personal]    Script Date: 30/10/2024 12:09:55 p. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Tipo_Personal](
	[id_tipo_personal] [int] IDENTITY(1,1) NOT NULL,
	[estado_id] [int] NULL,
	[nombre] [varchar](50) NOT NULL,
	[descripcion] [text] NULL,
PRIMARY KEY CLUSTERED 
(
	[id_tipo_personal] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY] TEXTIMAGE_ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Usuario]

-- %%
/****** Object:  Table [dbo].[Usuario]    Script Date: 30/10/2024 12:09:55 p. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Usuario](
	[id_usuario] [int] IDENTITY(1,1) NOT NULL,
	[rol_id] [int] NULL,
	[nombre_usuario] [varchar](50) NOT NULL,
	[contrasenia] [varchar](255) NOT NULL,
	[correo_electronico] [varchar](100) NOT NULL,
PRIMARY KEY CLUSTERED 
(
	[id_usuario] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Usuario_Rol]

-- %%
/****** Object:  Table [dbo].[Usuario_Rol]    Script Date: 30/10/2024 12:09:55 p. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Usuario_Rol](
	[usuario_id] [int] NOT NULL,
	[rol_id] [int] NOT NULL,
PRIMARY KEY CLUSTERED 
(
	[usuario_id] ASC,
	[rol_id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Categoria]

-- %%
SET IDENTITY_INSERT [dbo].[Categoria] ON 
INSERT [dbo].[Categoria] ([id_categoria], [estado_id], [nombre], [descripcion]) VALUES (1, 16, N'clasicas', N'Recetas tradicionales con ingredientes frescos.')
INSERT [dbo].[Categoria] ([id_categoria], [estado_id], [nombre], [descripcion]) VALUES (2, 16, N'exclusivas', N'Combinaciones únicas y sabores innovadores.
')
INSERT [dbo].[Categoria] ([id_categoria], [estado_id], [nombre], [descripcion]) VALUES (3, 16, N'tequeños y alitas', N'Tequeños crujientes y alitas jugosas con salsas.
')
INSERT [dbo].[Categoria] ([id_categoria], [estado_id], [nombre], [descripcion]) VALUES (4, 16, N'pan al ajo', N'Pan dorado y crujiente, infusionado con ajo.
')
INSERT [dbo].[Categoria] ([id_categoria], [estado_id], [nombre], [descripcion]) VALUES (5, 16, N'calzone', N'Pizza doblada con quesos y rellenos sabrosos.
')
INSERT [dbo].[Categoria] ([id_categoria], [estado_id], [nombre], [descripcion]) VALUES (6, 16, N'bebidas', NULL)
SET IDENTITY_INSERT [dbo].[Categoria] OFF
GO

-- %% [markdown]
-- # [dbo].[Estado]

-- %%
SET IDENTITY_INSERT [dbo].[Estado] ON 
INSERT [dbo].[Estado] ([id_estado], [nombre], [descripcion]) VALUES (16, N'Activo', N'se encuentra en uso')
INSERT [dbo].[Estado] ([id_estado], [nombre], [descripcion]) VALUES (17, N'Inactivo', N'Ya no se usa ')
INSERT [dbo].[Estado] ([id_estado], [nombre], [descripcion]) VALUES (18, N'Entregado', N'El pedido fue entregado')
INSERT [dbo].[Estado] ([id_estado], [nombre], [descripcion]) VALUES (19, N'En proceso', N'El pedido se esta realizando')
SET IDENTITY_INSERT [dbo].[Estado] OFF
GO

-- %% [markdown]
-- # [dbo].[Producto]

-- %%
SET IDENTITY_INSERT [dbo].[Producto] ON 
INSERT [dbo].[Producto] ([id_producto], [estado_id], [categoria_id], [nombre], [descripcion], [tamanio], [imagen_url], [precio]) VALUES (1, 16, 1, N'Caprese', N'Hojas de albaca frescas, tomate cherry y quero mozarella.', N'G', N'https://i.postimg.cc/ryZLRpcM/caprese.png', CAST(37.00 AS Decimal(4, 2)))
INSERT [dbo].[Producto] ([id_producto], [estado_id], [categoria_id], [nombre], [descripcion], [tamanio], [imagen_url], [precio]) VALUES (2, 16, 1, N'Americana', N'Pepperoni crujiente, queso mozzarella y salsa de tomate al estilo casero.', N'G', N'https://i.postimg.cc/L81RpFcR/americana.png', CAST(38.00 AS Decimal(4, 2)))
INSERT [dbo].[Producto] ([id_producto], [estado_id], [categoria_id], [nombre], [descripcion], [tamanio], [imagen_url], [precio]) VALUES (7, 16, 1, N'Hawaiana', N'Jugosa piña jamon y queso mozarella premium.', N'G', N'https://i.postimg.cc/SQnmr9gJ/hawaiana.png', CAST(39.00 AS Decimal(4, 2)))
INSERT [dbo].[Producto] ([id_producto], [estado_id], [categoria_id], [nombre], [descripcion], [tamanio], [imagen_url], [precio]) VALUES (8, 16, 1, N'Vegetariana', N'Frescos champiñones, aceitunas, cebolla pimiento y queso mozarella', N'G', N'https://i.postimg.cc/NFmVnQyP/vegetariana.png', CAST(42.00 AS Decimal(4, 2)))
INSERT [dbo].[Producto] ([id_producto], [estado_id], [categoria_id], [nombre], [descripcion], [tamanio], [imagen_url], [precio]) VALUES (9, 16, 1, N'Continental', N'Frescos champiñones, cebolla, aceitunas, jamón y queso mozarella', N'G', N'https://i.postimg.cc/Tw2Zhz4K/continental.png', CAST(40.00 AS Decimal(4, 2)))
INSERT [dbo].[Producto] ([id_producto], [estado_id], [categoria_id], [nombre], [descripcion], [tamanio], [imagen_url], [precio]) VALUES (10, 16, 1, N'Choripizza', N'Chorizo parrillero jugoso y queso mozzarella fundido.', N'G', N'https://i.postimg.cc/Qt6v7f20/choripizza.png', CAST(38.00 AS Decimal(4, 2)))
INSERT [dbo].[Producto] ([id_producto], [estado_id], [categoria_id], [nombre], [descripcion], [tamanio], [imagen_url], [precio]) VALUES (11, 16, 1, N'Pepperoni', N'Pepperoni dorado y queso mozzarella cremoso perfectamente derretido.', N'G', N'https://i.postimg.cc/vHRwtN1N/Pepperoni.png', CAST(38.00 AS Decimal(4, 2)))
INSERT [dbo].[Producto] ([id_producto], [estado_id], [categoria_id], [nombre], [descripcion], [tamanio], [imagen_url], [precio]) VALUES (12, 16, 1, N'Pizza Corazón', N'Convierte tu pizza grande en una pizza con forma de corazon.', N'G', N'https://i.postimg.cc/6qgSjy5Z/corazonpizza.png', CAST(40.00 AS Decimal(4, 2)))
INSERT [dbo].[Producto] ([id_producto], [estado_id], [categoria_id], [nombre], [descripcion], [tamanio], [imagen_url], [precio]) VALUES (13, 16, 1, N'Cuatro Quesos', N'Mezcla de queso mozzarella, cheddar, parmesano y queso azul.', N'G', N'https://i.postimg.cc/j2Lm4zKK/cuatroquesos.png', CAST(45.00 AS Decimal(4, 2)))
INSERT [dbo].[Producto] ([id_producto], [estado_id], [categoria_id], [nombre], [descripcion], [tamanio], [imagen_url], [precio]) VALUES (14, 16, 2, N'Tropical', N'Durazno jugoso, piña tropical, jamón y queso mozzarella cremoso.', N'G', N'https://i.postimg.cc/1X1P0dq0/sin-imagen.png', CAST(37.00 AS Decimal(4, 2)))
INSERT [dbo].[Producto] ([id_producto], [estado_id], [categoria_id], [nombre], [descripcion], [tamanio], [imagen_url], [precio]) VALUES (15, 16, 2, N'Diablita', N'Pepperoni, chorizo parrillero, rocoto y queso mozzarella.', N'G', N'https://i.postimg.cc/1X1P0dq0/sin-imagen.png', CAST(38.00 AS Decimal(4, 2)))
INSERT [dbo].[Producto] ([id_producto], [estado_id], [categoria_id], [nombre], [descripcion], [tamanio], [imagen_url], [precio]) VALUES (16, 16, 2, N'Full Meat', N'Carne, cabanossi, tocino, cebolla, pimiento y queso mozzarella.', N'G', N'https://i.postimg.cc/76LWqg57/full-meat.png', CAST(45.00 AS Decimal(4, 2)))
INSERT [dbo].[Producto] ([id_producto], [estado_id], [categoria_id], [nombre], [descripcion], [tamanio], [imagen_url], [precio]) VALUES (18, 16, 2, N'Pizza Burger', N'Hamburguesa de carne, tocino, cebolla, queso cheddar y queso mozzarella.', N'G', N'https://i.postimg.cc/DyyR5Qxs/pizza-burguer.png', CAST(42.00 AS Decimal(4, 2)))
INSERT [dbo].[Producto] ([id_producto], [estado_id], [categoria_id], [nombre], [descripcion], [tamanio], [imagen_url], [precio]) VALUES (19, 16, 2, N'Mix de Mr. Pizza', N'Jamón, chorizo parrilero, pimiento, aceituna, cebolla y queso mozzarella', N'G', N'https://i.postimg.cc/Qx1SQF35/Mix-de-Mr-Pizza.png', CAST(43.00 AS Decimal(4, 2)))
INSERT [dbo].[Producto] ([id_producto], [estado_id], [categoria_id], [nombre], [descripcion], [tamanio], [imagen_url], [precio]) VALUES (20, 16, 2, N'Míster Pizza', N'Jamón, piña, aceituna, tocino y queso mozzarella.', N'G', N'https://i.postimg.cc/1X1P0dq0/sin-imagen.png', CAST(43.00 AS Decimal(4, 2)))
INSERT [dbo].[Producto] ([id_producto], [estado_id], [categoria_id], [nombre], [descripcion], [tamanio], [imagen_url], [precio]) VALUES (21, 16, 2, N'Cuatro Sabores', N'Americana, hawaiana, pepperoni y choripizza.', N'G', N'https://i.postimg.cc/1X1P0dq0/sin-imagen.png', CAST(39.00 AS Decimal(4, 2)))
INSERT [dbo].[Producto] ([id_producto], [estado_id], [categoria_id], [nombre], [descripcion], [tamanio], [imagen_url], [precio]) VALUES (22, 16, 2, N'Carnevale', N'Ocho orillas con queso, chorizo, pepperoni, carne molida y queso cheddar.', N'G', N'https://i.postimg.cc/1X1P0dq0/sin-imagen.png', CAST(40.00 AS Decimal(4, 2)))
INSERT [dbo].[Producto] ([id_producto], [estado_id], [categoria_id], [nombre], [descripcion], [tamanio], [imagen_url], [precio]) VALUES (23, 16, 2, N'Mexicana', N'Queso cheddar, jalapeños, carne molida y un toque de salsa picante.', N'G', N'https://i.postimg.cc/1X1P0dq0/sin-imagen.png', CAST(45.00 AS Decimal(4, 2)))
INSERT [dbo].[Producto] ([id_producto], [estado_id], [categoria_id], [nombre], [descripcion], [tamanio], [imagen_url], [precio]) VALUES (24, 16, 3, N'Tequeños de jamón y queso', N'Doce pequeños de jamon y queso.', N'G', N'https://i.postimg.cc/6QpkQsSy/teque-os-de-jamon-y-queso.png', CAST(20.00 AS Decimal(4, 2)))
INSERT [dbo].[Producto] ([id_producto], [estado_id], [categoria_id], [nombre], [descripcion], [tamanio], [imagen_url], [precio]) VALUES (25, 16, 3, N'Tequeños de Lomo', N'Doce tequeños rellenos de lomo jugoso, crujientes y llenos de sabor.', N'G', N'https://i.postimg.cc/rpZv0nXg/teque-os-de-lomo.png', CAST(25.00 AS Decimal(4, 2)))
INSERT [dbo].[Producto] ([id_producto], [estado_id], [categoria_id], [nombre], [descripcion], [tamanio], [imagen_url], [precio]) VALUES (26, 16, 3, N'Alitas Cláscias', N'Seis alitas de broster, acompañadas de papas y ensalada.', N'G', N'https://i.postimg.cc/sXqd8nT1/pan-al-ajo-de-la-casa.png', CAST(25.00 AS Decimal(4, 2)))
INSERT [dbo].[Producto] ([id_producto], [estado_id], [categoria_id], [nombre], [descripcion], [tamanio], [imagen_url], [precio]) VALUES (27, 16, 3, N'Alitas a la BBQ', N'Seis alitas en salsa bbq, acompañadas de papas y ensalada.', N'G', N'https://i.postimg.cc/1X1P0dq0/sin-imagen.png', CAST(25.00 AS Decimal(4, 2)))
INSERT [dbo].[Producto] ([id_producto], [estado_id], [categoria_id], [nombre], [descripcion], [tamanio], [imagen_url], [precio]) VALUES (28, 16, 3, N'Alitas Orientales', N'Seis alitas en salsa oriental, acompañadas de papas y ensalada', N'G', N'https://i.postimg.cc/1X1P0dq0/sin-imagen.png', CAST(25.00 AS Decimal(4, 2)))
INSERT [dbo].[Producto] ([id_producto], [estado_id], [categoria_id], [nombre], [descripcion], [tamanio], [imagen_url], [precio]) VALUES (29, 16, 3, N'Alitas Acevichadas', N'Seis alitas en salsa acevichada, acompañadas de papas y ensalada.', N'G', N'https://i.postimg.cc/1X1P0dq0/sin-imagen.png', CAST(25.00 AS Decimal(4, 2)))
INSERT [dbo].[Producto] ([id_producto], [estado_id], [categoria_id], [nombre], [descripcion], [tamanio], [imagen_url], [precio]) VALUES (30, 16, 4, N'Pan al Ajo Tradicional', N'Doce piezas de pan al ajo en finas hiervas especiales.', N'G', N'https://i.postimg.cc/HW8C5gLM/pan-al-ajo-tradicional.png', CAST(15.00 AS Decimal(4, 2)))
INSERT [dbo].[Producto] ([id_producto], [estado_id], [categoria_id], [nombre], [descripcion], [tamanio], [imagen_url], [precio]) VALUES (31, 16, 4, N'Pan al Ajo Especial', N'Doce piezas de pan al ajo en finas hiervas y queso mozzarella.', N'G', N'https://i.postimg.cc/D0GkKqN6/pan-al-ajo-especial.png', CAST(20.00 AS Decimal(4, 2)))
INSERT [dbo].[Producto] ([id_producto], [estado_id], [categoria_id], [nombre], [descripcion], [tamanio], [imagen_url], [precio]) VALUES (32, 16, 4, N'Pan al Ajo de la Casa', N'Hecho con maza pizzera, albahaca, ajo y un toque de queso mozzarella(Ocho piezas).', N'G', N'https://i.postimg.cc/sXqd8nT1/pan-al-ajo-de-la-casa.png', CAST(18.00 AS Decimal(4, 2)))
INSERT [dbo].[Producto] ([id_producto], [estado_id], [categoria_id], [nombre], [descripcion], [tamanio], [imagen_url], [precio]) VALUES (33, 16, 5, N'Calzone Full Meat', N'Carne, cabanossi, tocino, cebolla, pimiento y queso mozzarella.', N'G', N'https://i.postimg.cc/DZ2KLJ8y/calzone-de-carne.png', CAST(26.00 AS Decimal(4, 2)))
INSERT [dbo].[Producto] ([id_producto], [estado_id], [categoria_id], [nombre], [descripcion], [tamanio], [imagen_url], [precio]) VALUES (34, 16, 5, N'Calzone Hawaiano', N'Jugosa piña con jamón y queso mozzarella derretido.', N'G', N'https://i.postimg.cc/JnPCqrk3/calzone-hawaiano.png', CAST(24.00 AS Decimal(4, 2)))
INSERT [dbo].[Producto] ([id_producto], [estado_id], [categoria_id], [nombre], [descripcion], [tamanio], [imagen_url], [precio]) VALUES (35, 16, 5, N'Calzone Vegetariano', N'Champiñones, cebolla, aceitunas, pimiento y queso mozzarella.', N'G', N'https://i.postimg.cc/WzyRB5Sh/calzone-vegetariano.png', CAST(25.00 AS Decimal(4, 2)))
INSERT [dbo].[Producto] ([id_producto], [estado_id], [categoria_id], [nombre], [descripcion], [tamanio], [imagen_url], [precio]) VALUES (36, 16, 6, N'Agua Mineral', N'620ML', N'P', N'https://i.postimg.cc/YqjMdW8v/agua.png', CAST(3.50 AS Decimal(4, 2)))
INSERT [dbo].[Producto] ([id_producto], [estado_id], [categoria_id], [nombre], [descripcion], [tamanio], [imagen_url], [precio]) VALUES (37, 16, 6, N'Guaraná', N'500ML', N'P', N'https://i.postimg.cc/zvb2g8SG/guarana.png', CAST(3.50 AS Decimal(4, 2)))
INSERT [dbo].[Producto] ([id_producto], [estado_id], [categoria_id], [nombre], [descripcion], [tamanio], [imagen_url], [precio]) VALUES (38, 16, 6, N'Coca Cola', N'500mML', N'P', N'https://i.postimg.cc/13wxdcF3/coca-cola.png', CAST(4.00 AS Decimal(4, 2)))
INSERT [dbo].[Producto] ([id_producto], [estado_id], [categoria_id], [nombre], [descripcion], [tamanio], [imagen_url], [precio]) VALUES (39, 16, 6, N'Inca Kola', N'500ML', N'P', N'https://i.postimg.cc/c49x2FyW/Inca-Cola.png', CAST(4.00 AS Decimal(4, 2)))
INSERT [dbo].[Producto] ([id_producto], [estado_id], [categoria_id], [nombre], [descripcion], [tamanio], [imagen_url], [precio]) VALUES (40, 16, 6, N'Coca Cola', N'2.5L', N'G', N'https://i.postimg.cc/52ztz8TM/Coca-cola-2-5-L.png', CAST(12.00 AS Decimal(4, 2)))
INSERT [dbo].[Producto] ([id_producto], [estado_id], [categoria_id], [nombre], [descripcion], [tamanio], [imagen_url], [precio]) VALUES (41, 16, 6, N'Inca Kola', N'2.5L', N'G', N'https://i.postimg.cc/K8tJHswp/Inca-Cola-2-5-L.png', CAST(12.00 AS Decimal(4, 2)))
INSERT [dbo].[Producto] ([id_producto], [estado_id], [categoria_id], [nombre], [descripcion], [tamanio], [imagen_url], [precio]) VALUES (42, 16, 6, N'Inca Kola', N'2L retornable', N'G', N'https://i.postimg.cc/FRkZ0Wyx/Inca-Kola-2-L-retornable.png', CAST(9.00 AS Decimal(4, 2)))
INSERT [dbo].[Producto] ([id_producto], [estado_id], [categoria_id], [nombre], [descripcion], [tamanio], [imagen_url], [precio]) VALUES (43, 16, 6, N'Guaraná', N'3L', N'G', N'https://i.postimg.cc/YCXfZK83/Guaran-3-L.png', CAST(10.00 AS Decimal(4, 2)))
INSERT [dbo].[Producto] ([id_producto], [estado_id], [categoria_id], [nombre], [descripcion], [tamanio], [imagen_url], [precio]) VALUES (45, 16, 6, N'Sprite', N'2.2L', N'G', N'https://i.postimg.cc/x80X9q1b/Sprite-2-2-L.png', CAST(9.00 AS Decimal(4, 2)))
SET IDENTITY_INSERT [dbo].[Producto] OFF
GO

-- %% [markdown]
-- # [FK__Carrito__cliente__59FA5E80]

-- %%
ALTER TABLE [dbo].[Carrito]  WITH CHECK ADD FOREIGN KEY([cliente_id])
REFERENCES [dbo].[Cliente] ([id_cliente])
GO

-- %% [markdown]
-- # [FK__Categoria__estad__3C69FB99]

-- %%
ALTER TABLE [dbo].[Categoria]  WITH CHECK ADD FOREIGN KEY([estado_id])
REFERENCES [dbo].[Estado] ([id_estado])
GO

-- %% [markdown]
-- # [FK__Cliente__usuario__49C3F6B7]

-- %%
ALTER TABLE [dbo].[Cliente]  WITH CHECK ADD FOREIGN KEY([usuario_id])
REFERENCES [dbo].[Usuario] ([id_usuario])
GO

-- %% [markdown]
-- # [FK__Detalle_C__carri__5CD6CB2B]

-- %%
ALTER TABLE [dbo].[Detalle_Carrito]  WITH CHECK ADD FOREIGN KEY([carrito_id])
REFERENCES [dbo].[Carrito] ([id_carrito])
GO

-- %% [markdown]
-- # [FK__Detalle_C__produ__5DCAEF64]

-- %%
ALTER TABLE [dbo].[Detalle_Carrito]  WITH CHECK ADD FOREIGN KEY([producto_id])
REFERENCES [dbo].[Producto] ([id_producto])
GO

-- %% [markdown]
-- # [FK__Detalle_P__pedid__5629CD9C]

-- %%
ALTER TABLE [dbo].[Detalle_Pedido]  WITH CHECK ADD FOREIGN KEY([pedido_id])
REFERENCES [dbo].[Pedido] ([id_pedido])
GO

-- %% [markdown]
-- # [FK__Detalle_P__produ__571DF1D5]

-- %%
ALTER TABLE [dbo].[Detalle_Pedido]  WITH CHECK ADD FOREIGN KEY([producto_id])
REFERENCES [dbo].[Producto] ([id_producto])
GO

-- %% [markdown]
-- # [FK__Pedido__cliente___4CA06362]

-- %%
ALTER TABLE [dbo].[Pedido]  WITH CHECK ADD FOREIGN KEY([cliente_id])
REFERENCES [dbo].[Cliente] ([id_cliente])
GO

-- %% [markdown]
-- # [FK__Pedido__cocinero__4D94879B]

-- %%
ALTER TABLE [dbo].[Pedido]  WITH CHECK ADD FOREIGN KEY([cocinero_id])
REFERENCES [dbo].[Personal] ([id_personal])
GO

-- %% [markdown]
-- # [FK__Pedido__estado_i__4F7CD00D]

-- %%
ALTER TABLE [dbo].[Pedido]  WITH CHECK ADD FOREIGN KEY([estado_id])
REFERENCES [dbo].[Estado] ([id_estado])
GO

-- %% [markdown]
-- # [FK__Pedido__repartid__4E88ABD4]

-- %%
ALTER TABLE [dbo].[Pedido]  WITH CHECK ADD FOREIGN KEY([repartidor_id])
REFERENCES [dbo].[Personal] ([id_personal])
GO

-- %% [markdown]
-- # [FK__Personal__estado__46E78A0C]

-- %%
ALTER TABLE [dbo].[Personal]  WITH CHECK ADD FOREIGN KEY([estado_id])
REFERENCES [dbo].[Estado] ([id_estado])
GO

-- %% [markdown]
-- # [FK__Personal__tipo_p__45F365D3]

-- %%
ALTER TABLE [dbo].[Personal]  WITH CHECK ADD FOREIGN KEY([tipo_personal_id])
REFERENCES [dbo].[Tipo_Personal] ([id_tipo_personal])
GO

-- %% [markdown]
-- # [FK__Personal__usuari__44FF419A]

-- %%
ALTER TABLE [dbo].[Personal]  WITH CHECK ADD FOREIGN KEY([usuario_id])
REFERENCES [dbo].[Usuario] ([id_usuario])
GO

-- %% [markdown]
-- # [FK__Producto__catego__534D60F1]

-- %%
ALTER TABLE [dbo].[Producto]  WITH CHECK ADD FOREIGN KEY([categoria_id])
REFERENCES [dbo].[Categoria] ([id_categoria])
GO

-- %% [markdown]
-- # [FK__Producto__estado__52593CB8]

-- %%
ALTER TABLE [dbo].[Producto]  WITH CHECK ADD FOREIGN KEY([estado_id])
REFERENCES [dbo].[Estado] ([id_estado])
GO

-- %% [markdown]
-- # [FK__Rol__estado_id__3F466844]

-- %%
ALTER TABLE [dbo].[Rol]  WITH CHECK ADD FOREIGN KEY([estado_id])
REFERENCES [dbo].[Estado] ([id_estado])
GO

-- %% [markdown]
-- # [FK__Tipo_Pers__estad__398D8EEE]

-- %%
ALTER TABLE [dbo].[Tipo_Personal]  WITH CHECK ADD FOREIGN KEY([estado_id])
REFERENCES [dbo].[Estado] ([id_estado])
GO

-- %% [markdown]
-- # [FK__Usuario__rol_id__4222D4EF]

-- %%
ALTER TABLE [dbo].[Usuario]  WITH CHECK ADD FOREIGN KEY([rol_id])
REFERENCES [dbo].[Rol] ([id_rol])
GO

-- %% [markdown]
-- # [FK__Usuario_R__rol_i__619B8048]

-- %%
ALTER TABLE [dbo].[Usuario_Rol]  WITH CHECK ADD FOREIGN KEY([rol_id])
REFERENCES [dbo].[Rol] ([id_rol])
GO

-- %% [markdown]
-- # [FK__Usuario_R__usuar__60A75C0F]

-- %%
ALTER TABLE [dbo].[Usuario_Rol]  WITH CHECK ADD FOREIGN KEY([usuario_id])
REFERENCES [dbo].[Usuario] ([id_usuario])
GO

-- %% [markdown]
-- # [MrPizza]

-- %%
USE [master]
GO

-- %%
ALTER DATABASE [MrPizza] SET  READ_WRITE 
GO
